# %% [markdown]
# # Change data formatting to a wide table

# %%
import pandas as pd

df_iea = pd.read_csv('../../data/raw/IEA Global EV Data 2024.csv')
df_iea.head()
# Out:
#       region    category       parameter  mode powertrain  year      unit  \
# 0  Australia  Historical  EV stock share  Cars         EV  2011   percent
# 1  Australia  Historical  EV sales share  Cars         EV  2011   percent
# 2  Australia  Historical        EV sales  Cars        BEV  2011  Vehicles
# 3  Australia  Historical        EV stock  Cars        BEV  2011  Vehicles
# 4  Australia  Historical        EV stock  Cars        BEV  2012  Vehicles
#
#        value
# 0    0.00039
# 1    0.00650
# 2   49.00000
# 3   49.00000
# 4  220.00000

# %%
df_wide = df_iea.pivot_table(
    index=['region', 'year', 'category', 'mode', 'powertrain'],
    columns='parameter',
    values='value',
    aggfunc='first'
).reset_index()

df_wide.columns = [col.lower().replace(' ', '_') for col in df_wide.columns]
df_wide.head()
# Out:
#       region  year    category  mode powertrain  ev_charging_points  ev_sales  \
# 0  Australia  2011  Historical  Cars        BEV                 NaN      49.0
# 1  Australia  2011  Historical  Cars         EV                 NaN       NaN
# 2  Australia  2012  Historical  Cars        BEV                 NaN     170.0
# 3  Australia  2012  Historical  Cars         EV                 NaN       NaN
# 4  Australia  2012  Historical  Cars       PHEV                 NaN      80.0
#
#    ev_sales_share  ev_stock  ev_stock_share  electricity_demand  \
# 0             NaN      49.0             NaN                 NaN
# 1          0.0065       NaN         0.00039                 NaN
# 2             NaN     220.0             NaN                 NaN
# 3          0.0300       NaN         0.00240                 NaN
# 4             NaN      80.0             NaN                 NaN
#
#    oil_displacement_mbd  oil_displacement,_million_lge
# 0                   NaN                            NaN
# ...

# %%
df_wide.to_csv('../../data/processed/iea_wide_format.csv', index=False)
print(f"Saved: {len(df_wide)} rows, {len(df_wide.columns)} columns")
# Out:
# Saved: 6464 rows, 13 columns
