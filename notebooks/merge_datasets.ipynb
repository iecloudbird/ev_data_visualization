# %%
import pandas as pd

df_iea = pd.read_csv('../data/processed/iea_wide_format.csv')
df_stations = pd.read_csv('../data/processed/stations_enhanced.csv')

# %%
station_stats = df_stations.groupby('country').agg({
    'Station ID': 'count',
    'Cost (USD/kWh)': 'mean',
    'Reviews (Rating)': 'mean',
    'is_fast_charger': 'mean',
    'is_renewable': 'mean',
    'is_24_7': 'mean',
    'Usage Stats (avg users/day)': 'mean'
}).rename(columns={
    'Station ID': 'total_stations',
    'Cost (USD/kWh)': 'avg_cost_per_kwh',
    'Reviews (Rating)': 'avg_rating',
    'is_fast_charger': 'fast_charger_ratio',
    'is_renewable': 'renewable_ratio',
    'is_24_7': 'always_available_ratio',
    'Usage Stats (avg users/day)': 'avg_daily_users'
})

station_stats.head()
# Out:
#            total_stations  avg_cost_per_kwh  avg_rating  fast_charger_ratio  \
# country
# Australia             295          0.306576    4.042373            0.301695
# Brazil                279          0.290609    3.992832            0.322581
# Canada                257          0.296070    4.021012            0.346304
# China                 319          0.306050    4.016928            0.288401
# Germany               292          0.304897    3.947603            0.339041
#
#            renewable_ratio  always_available_ratio  avg_daily_users
# country
# Australia         0.515254                0.308475        55.559322
# Brazil            0.505376                0.383513        52.311828
# Canada            0.470817                0.322957        56.719844
# China             0.514107                0.332288        56.692790
# Germany           0.472603                0.359589        55.527397

# %%
df_merged = df_iea.merge(
    station_stats,
    left_on='region',
    right_index=True,
    how='left'
)

df_merged.head()
# Out:
#       region  year    category  mode powertrain  ev_charging_points  ev_sales  \
# 0  Australia  2011  Historical  Cars        BEV                 NaN      49.0
# 1  Australia  2011  Historical  Cars         EV                 NaN       NaN
# 2  Australia  2012  Historical  Cars        BEV                 NaN     170.0
# 3  Australia  2012  Historical  Cars         EV                 NaN       NaN
# 4  Australia  2012  Historical  Cars       PHEV                 NaN      80.0
#
#    ev_sales_share  ev_stock  ev_stock_share  electricity_demand  \
# 0             NaN      49.0             NaN                 NaN
# 1          0.0065       NaN         0.00039                 NaN
# 2             NaN     220.0             NaN                 NaN
# 3          0.0300       NaN         0.00240                 NaN
# 4             NaN      80.0             NaN                 NaN
#
#    oil_displacement_mbd  oil_displacement,_million_lge  total_stations  \
# 0                   NaN                            NaN           295.0
# 1                   NaN                            NaN           295.0
# 2                   NaN                            NaN           295.0
# 3                   NaN                            NaN           295.0
# 4                   NaN                            NaN           295.0
#
#    avg_cost_per_kwh  avg_rating  fast_charger_ratio  renewable_ratio  \
# 0          0.306576    4.042373            0.301695         0.515254
# 1          0.306576    4.042373            0.301695         0.515254
# 2          0.306576    4.042373            0.301695         0.515254
# 3          0.306576    4.042373            0.301695         0.515254
# 4          0.306576    4.042373            0.301695         0.515254
#
#    always_available_ratio  avg_daily_users
# 0                0.308475        55.559322
# 1                0.308475        55.559322
# 2                0.308475        55.559322
# 3                0.308475        55.559322
# 4                0.308475        55.559322

# %%
df_merged['stations_per_million_evs'] = (
    df_merged['total_stations'] / (df_merged['ev_stock'] / 1_000_000)
)

# %%
df_merged = df_merged[df_merged['category'] == 'Historical'].copy()

df_merged.head()
# Out:
#       region  year    category  mode powertrain  ev_charging_points  ev_sales  \
# 0  Australia  2011  Historical  Cars        BEV                 NaN      49.0
# 1  Australia  2011  Historical  Cars         EV                 NaN       NaN
# 2  Australia  2012  Historical  Cars        BEV                 NaN     170.0
# 3  Australia  2012  Historical  Cars         EV                 NaN       NaN
# 4  Australia  2012  Historical  Cars       PHEV                 NaN      80.0
#
#    ev_sales_share  ev_stock  ev_stock_share  ...  oil_displacement_mbd  \
# 0             NaN      49.0             NaN  ...                   NaN
# 1          0.0065       NaN         0.00039  ...                   NaN
# 2             NaN     220.0             NaN  ...                   NaN
# 3          0.0300       NaN         0.00240  ...                   NaN
# 4             NaN      80.0             NaN  ...                   NaN
#
#    oil_displacement,_million_lge  total_stations  avg_cost_per_kwh  \
# 0                            NaN           295.0          0.306576
# 1                            NaN           295.0          0.306576
# 2                            NaN           295.0          0.306576
# 3                            NaN           295.0          0.306576
# 4                            NaN           295.0          0.306576
#
#    avg_rating  fast_charger_ratio  renewable_ratio  always_available_ratio  \
# 0    4.042373            0.301695         0.515254                0.308475
# 1    4.042373            0.301695         0.515254                0.308475
# 2    4.042373            0.301695         0.515254                0.308475
# 3    4.042373            0.301695         0.515254                0.308475
# 4    4.042373            0.301695         0.515254                0.308475
#
#    avg_daily_users  stations_per_million_evs
# 0        55.559322              6.020408e+06
# 1        55.559322                       NaN
# 2        55.559322              1.340909e+06
# 3        55.559322                       NaN
# 4        55.559322              3.687500e+06
#
# [5 rows x 21 columns]

# %%
df_merged.to_csv('../data/processed/merged_dataset.csv', index=False)
print(f"Saved: {len(df_merged)} rows, {len(df_merged.columns)} columns")
# Out:
# Saved: 5085 rows, 21 columns
